# %%
import pandas as pd

# %%
df = pd.read_csv('x86instrdesc.csv',sep='=', header=None)

# %%
df
# Out:
#                                0        1
# 0                          PHI\t       0,
# 1                    INLINEASM\t       1,
# 2                 INLINEASM_BR\t       2,
# 3              CFI_INSTRUCTION\t       3,
# 4                     EH_LABEL\t       4,
# ...                          ...      ...
# 15244                    XSHA1\t   15244,
# 15245                  XSHA256\t   15245,
# 15246                   XSTORE\t   15246,
# 15247                    XTEST\t   15247,
# 15248      INSTRUCTION_LIST_END     15248
#
# [15249 rows x 2 columns]

# %%
ext = df[0].str.extract('(?P<date>[a-zA-Z_]+)', expand=True)

# %%
df.insert(0, "Extracted", ext, True)

# %%
df
# Out:
#                   Extracted                          0        1
# 0                       PHI                      PHI\t       0,
# 1                 INLINEASM                INLINEASM\t       1,
# 2              INLINEASM_BR             INLINEASM_BR\t       2,
# 3           CFI_INSTRUCTION          CFI_INSTRUCTION\t       3,
# 4                  EH_LABEL                 EH_LABEL\t       4,
# ...                     ...                        ...      ...
# 15244                  XSHA                    XSHA1\t   15244,
# 15245                  XSHA                  XSHA256\t   15245,
# 15246                XSTORE                   XSTORE\t   15246,
# 15247                 XTEST                    XTEST\t   15247,
# 15248  INSTRUCTION_LIST_END      INSTRUCTION_LIST_END     15248
#
# [15249 rows x 3 columns]

# %%
df['Extracted'][
# Out:
# 0                         PHI
# 1                   INLINEASM
# 2                INLINEASM_BR
# 3             CFI_INSTRUCTION
# 4                    EH_LABEL
#                  ...
# 15244                    XSHA
# 15245                    XSHA
# 15246                  XSTORE
# 15247                   XTEST
# 15248    INSTRUCTION_LIST_END
# Name: Extracted, Length: 15249, dtype: object

# %%
df.to_csv('extracted_x86.csv',header=False)

# %%
grouped = df.groupby(['Extracted'])

# %%
print(grouped['Extracted'])
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x1488a4f10e50>

# %%
for key, item in grouped:
    print(key)
#     print(item)
    print(grouped.get_group(key), "\n\n")
    print(grouped.get_group(key).index, "\n\n")
# Out:
# AAA
#     Extracted          0      1
# 254       AAA      AAA\t   254,
#
#
# Int64Index([254], dtype='int64')
#
#
# AAD
#     Extracted             0      1
# 255       AAD      AAD8i8\t   255,
#
#
# Int64Index([255], dtype='int64')
#
#
# AAM
#     Extracted             0      1
# 256       AAM      AAM8i8\t   256,
#
#
# Int64Index([256], dtype='int64')
#
#
# AAS
#     Extracted          0      1
# 257       AAS      AAS\t   257,
#
#
# Int64Index([257], dtype='int64')
#
#
# ABS_F
#     Extracted            0      1
# 258     ABS_F      ABS_F\t   258,
#
#
# Int64Index([258], dtype='int64')
#
#
# ABS_Fp
#     Extracted               0      1
# 259    ABS_Fp      ABS_Fp32\t   259,
# 260    ABS_Fp      ABS_Fp64\t   260,
# 261    ABS_Fp      ABS_Fp80\t   261,
#
#
# Int64Index([259, 260, 261], dtype='int64')
#
#
# ADC
#     Extracted                  0      1
# 262       ADC         ADC16i16\t   262,
# 263       ADC          ADC16mi\t   263,
# 264       ADC         ADC16mi8\t   264,
# 265       ADC          ADC16mr\t   265,
# 266       ADC          ADC16ri\t   266,
# 267       ADC         ADC16ri8\t   267,
# 268       ADC          ADC16rm\t   268,
# 269       ADC          ADC16rr\t   269,
# 270       ADC      ADC16rr_REV\t   270,
# 271       ADC         ADC32i32\t   271,
# 272       ADC          ADC32mi\t   272,
# 273       ADC         ADC32mi8\t   273,
# 274       ADC          ADC32mr\t   274,
# 275       ADC          ADC32ri\t   275,
# 276       ADC         ADC32ri8\t   276,
# 277       ADC          ADC32rm\t   277,
# 278       ADC          ADC32rr\t   278,
# 279       ADC      ADC32rr_REV\t   279,
# 280       ADC         ADC64i32\t   280,
# 281       ADC        ADC64mi32\t   281,
# 282       ADC         ADC64mi8\t   282,
# 283       ADC          ADC64mr\t   283,
# 284       ADC        ADC64ri32\t   284,
# 285       ADC         ADC64ri8\t   285,
# 286       ADC          ADC64rm\t   286,
# 287       ADC          ADC64rr\t   287,
# 288       ADC      ADC64rr_REV\t   288,
# 289       ADC           ADC8i8\t   289,
# 290       ADC           ADC8mi\t   290,
# 291       ADC          ADC8mi8\t   291,
# 292       ADC           ADC8mr\t   292,
# 293       ADC           ADC8ri\t   293,
# 294       ADC          ADC8ri8\t   294,
# 295       ADC           ADC8rm\t   295,
# 296       ADC           ADC8rr\t   296,
# 297       ADC       ADC8rr_REV\t   297,
#
#
# Int64Index([262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274,
#             275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287,
#             288, 289, 290, 291, 292, 293, 294, 295, 296, 297],
#            dtype='int64')
#
#
# ADCX
#     Extracted               0      1
# 298      ADCX      ADCX32rm\t   298,
# 299      ADCX      ADCX32rr\t   299,
# 300      ADCX      ADCX64rm\t   300,
# 301      ADCX      ADCX64rr\t   301,
#
#
# Int64Index([298, 299, 300, 301], dtype='int64')
#
#
# ADD
#     Extracted                   0      1
# 177       ADD       ADD16ri8_DB\t   177,
# 178       ADD        ADD16ri_DB\t   178,
# 179       ADD        ADD16rr_DB\t   179,
# 180       ADD       ADD32ri8_DB\t   180,
# 181       ADD        ADD32ri_DB\t   181,
# 182       ADD        ADD32rr_DB\t   182,
# 183       ADD      ADD64ri32_DB\t   183,
# 184       ADD       ADD64ri8_DB\t   184,
# 185       ADD        ADD64rr_DB\t   185,
# 186       ADD         ADD8ri_DB\t   186,
# 187       ADD         ADD8rr_DB\t   187,
# 302       ADD          ADD16i16\t   302,
# 303       ADD           ADD16mi\t   303,
# 304       ADD          ADD16mi8\t   304,
# 305       ADD           ADD16mr\t   305,
# 306       ADD           ADD16ri\t   306,
# 307       ADD          ADD16ri8\t   307,
# 308       ADD           ADD16rm\t   308,
# 309       ADD           ADD16rr\t   309,
# 310       ADD       ADD16rr_REV\t   310,
# 311       ADD          ADD32i32\t   311,
# 312       ADD           ADD32mi\t   312,
# 313       ADD          ADD32mi8\t   313,
# 314       ADD           ADD32mr\t   314,
# 315       ADD           ADD32ri\t   315,
# 316       ADD          ADD32ri8\t   316,
# 317       ADD           ADD32rm\t   317,
# 318       ADD           ADD32rr\t   318,
# 319       ADD       ADD32rr_REV\t   319,
# 320       ADD          ADD64i32\t   320,
# 321       ADD         ADD64mi32\t   321,
# 322       ADD          ADD64mi8\t   322,
# 323       ADD           ADD64mr\t   323,
# 324       ADD         ADD64ri32\t   324,
# 325       ADD          ADD64ri8\t   325,
# 326       ADD           ADD64rm\t   326,
# 327       ADD           ADD64rr\t   327,
# 328       ADD       ADD64rr_REV\t   328,
# 329       ADD            ADD8i8\t   329,
# 330       ADD            ADD8mi\t   330,
# 331       ADD           ADD8mi8\t   331,
# 332       ADD            ADD8mr\t   332,
# 333       ADD            ADD8ri\t   333,
# 334       ADD           ADD8ri8\t   334,
# 335       ADD            ADD8rm\t   335,
# 336       ADD            ADD8rr\t   336,
# 337       ADD        ADD8rr_REV\t   337,
#
#
# Int64Index([177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 302, 303,
#             304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316,
#             317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329,
#             330, 331, 332, 333, 334, 335, 336, 337],
#            dtype='int64')
#
#
# ADDPDrm
#     Extracted              0      1
# 338   ADDPDrm      ADDPDrm\t   338,
#
#
# Int64Index([338], dtype='int64')
#
#
# ADDPDrr
#     Extracted              0      1
# 339   ADDPDrr      ADDPDrr\t   339,
#
#
# Int64Index([339], dtype='int64')
#
#
# ADDPSrm
#     Extracted              0      1
# 340   ADDPSrm      ADDPSrm\t   340,
#
#
# Int64Index([340], dtype='int64')
#
#
# ADDPSrr
#     Extracted              0      1
# 341   ADDPSrr      ADDPSrr\t   341,
#
#
# Int64Index([341], dtype='int64')
#
#
# ADDSDrm
#     Extracted              0      1
# 342   ADDSDrm      ADDSDrm\t   342,
#
#
# Int64Index([342], dtype='int64')
#
#
# ADDSDrm_Int
#        Extracted                  0      1
# 343  ADDSDrm_Int      ADDSDrm_Int\t   343,
#
#
# Int64Index([343], dtype='int64')
#
#
# ADDSDrr
#     Extracted              0      1
# 344   ADDSDrr      ADDSDrr\t   344,
#
#
# Int64Index([344], dtype='int64')
#
#
# ADDSDrr_Int
#        Extracted                  0      1
# 345  ADDSDrr_Int      ADDSDrr_Int\t   345,
#
#
# Int64Index([345], dtype='int64')
#
#
# ADDSSrm
#     Extracted              0      1
# 346   ADDSSrm      ADDSSrm\t   346,
#
#
# Int64Index([346], dtype='int64')
#
#
# ADDSSrm_Int
#        Extracted                  0      1
# 347  ADDSSrm_Int      ADDSSrm_Int\t   347,
#
#
# Int64Index([347], dtype='int64')
#
#
# ADDSSrr
#     Extracted              0      1
# 348   ADDSSrr      ADDSSrr\t   348,
#
#
# Int64Index([348], dtype='int64')
#
#
# ADDSSrr_Int
#        Extracted                  0      1
# 349  ADDSSrr_Int      ADDSSrr_Int\t   349,
#
#
# Int64Index([349], dtype='int64')
#
#
# ADDSUBPDrm
#       Extracted                 0      1
# 350  ADDSUBPDrm      ADDSUBPDrm\t   350,
#
#
# Int64Index([350], dtype='int64')
#
#
# ADDSUBPDrr
#       Extracted                 0      1
# 351  ADDSUBPDrr      ADDSUBPDrr\t   351,
#
#
# Int64Index([351], dtype='int64')
#
#
# ADDSUBPSrm
#       Extracted                 0      1
# 352  ADDSUBPSrm      ADDSUBPSrm\t   352,
#
#
# Int64Index([352], dtype='int64')
#
#
# ADDSUBPSrr
#       Extracted                 0      1
# 353  ADDSUBPSrr      ADDSUBPSrr\t   353,
#
#
# Int64Index([353], dtype='int64')
#
#
# ADD_F
#     Extracted               0      1
# 354     ADD_F      ADD_F32m\t   354,
# 355     ADD_F      ADD_F64m\t   355,
#
#
# Int64Index([354, 355], dtype='int64')
#
#
# ADD_FI
#     Extracted                0      1
# 356    ADD_FI      ADD_FI16m\t   356,
# 357    ADD_FI      ADD_FI32m\t   357,
#
#
# Int64Index([356, 357], dtype='int64')
#
#
# ADD_FPrST
#      Extracted                 0      1
# 358  ADD_FPrST      ADD_FPrST0\t   358,
#
#
# Int64Index([358], dtype='int64')
#
#
# ADD_FST
#     Extracted                0      1
# 359   ADD_FST      ADD_FST0r\t   359,
#
#
# Int64Index([359], dtype='int64')
#
#
# ADD_Fp
#     Extracted                  0      1
# 360    ADD_Fp         ADD_Fp32\t   360,
# 361    ADD_Fp        ADD_Fp32m\t   361,
# 362    ADD_Fp         ADD_Fp64\t   362,
# 363    ADD_Fp        ADD_Fp64m\t   363,
# 364    ADD_Fp      ADD_Fp64m32\t   364,
# 365    ADD_Fp         ADD_Fp80\t   365,
# 366    ADD_Fp      ADD_Fp80m32\t   366,
# 367    ADD_Fp      ADD_Fp80m64\t   367,
#
#
# Int64Index([360, 361, 362, 363, 364, 365, 366, 367], dtype='int64')
#
#
# ADD_FpI
#     Extracted                   0      1
# 368   ADD_FpI      ADD_FpI16m32\t   368,
# 369   ADD_FpI      ADD_FpI16m64\t   369,
# 370   ADD_FpI      ADD_FpI16m80\t   370,
# 371   ADD_FpI      ADD_FpI32m32\t   371,
# 372   ADD_FpI      ADD_FpI32m64\t   372,
# 373   ADD_FpI      ADD_FpI32m80\t   373,
#
#
# Int64Index([368, 369, 370, 371, 372, 373], dtype='int64')
#
#
# ADD_FrST
#     Extracted                0      1
# 374  ADD_FrST      ADD_FrST0\t   374,
#
#
# Int64Index([374], dtype='int64')
#
#
# ADJCALLSTACKDOWN
#             Extracted                         0      1
# 375  ADJCALLSTACKDOWN      ADJCALLSTACKDOWN32\t   375,
# 376  ADJCALLSTACKDOWN      ADJCALLSTACKDOWN64\t   376,
#
#
# Int64Index([375, 376], dtype='int64')
#
#
# ADJCALLSTACKUP
#           Extracted                       0      1
# 377  ADJCALLSTACKUP      ADJCALLSTACKUP32\t   377,
# 378  ADJCALLSTACKUP      ADJCALLSTACKUP64\t   378,
#
#
# Int64Index([377, 378], dtype='int64')
#
#
# ADOX
#     Extracted               0      1
# 379      ADOX      ADOX32rm\t   379,
# 380      ADOX      ADOX32rr\t   380,
# 381      ADOX      ADOX64rm\t   381,
# 382      ADOX      ADOX64rr\t   382,
#
#
# Int64Index([379, 380, 381, 382], dtype='int64')
#
#
# AESDECLASTrm
#         Extracted                   0      1
# 383  AESDECLASTrm      AESDECLASTrm\t   383,
#
#
# Int64Index([383], dtype='int64')
#
#
# AESDECLASTrr
#         Extracted                   0      1
# 384  AESDECLASTrr      AESDECLASTrr\t   384,
#
#
# Int64Index([384], dtype='int64')
#
#
# AESDECrm
#     Extracted               0      1
# 385  AESDECrm      AESDECrm\t   385,
#
#
# Int64Index([385], dtype='int64')
#
#
# AESDECrr
#     Extracted               0      1
# 386  AESDECrr      AESDECrr\t   386,
#
#
# Int64Index([386], dtype='int64')
#
#
# AESENCLASTrm
#         Extracted                   0      1
# 387  AESENCLASTrm      AESENCLASTrm\t   387,
#
#
# Int64Index([387], dtype='int64')
#
#
# AESENCLASTrr
#         Extracted                   0      1
# 388  AESENCLASTrr      AESENCLASTrr\t   388,
#
#
# Int64Index([388], dtype='int64')
#
#
# AESENCrm
#     Extracted               0      1
# 389  AESENCrm      AESENCrm\t   389,
#
#
# Int64Index([389], dtype='int64')
#
#
# AESENCrr
#     Extracted               0      1
# 390  AESENCrr      AESENCrr\t   390,
#
#
# Int64Index([390], dtype='int64')
#
#
# AESIMCrm
#     Extracted               0      1
# 391  AESIMCrm      AESIMCrm\t   391,
#
#
# Int64Index([391], dtype='int64')
#
#
# AESIMCrr
#     Extracted               0      1
# 392  AESIMCrr      AESIMCrr\t   392,
#
#
# Int64Index([392], dtype='int64')
#
#
# AESKEYGENASSIST
#            Extracted                           0      1
# 393  AESKEYGENASSIST      AESKEYGENASSIST128rm\t   393,
# 394  AESKEYGENASSIST      AESKEYGENASSIST128rr\t   394,
#
#
# Int64Index([393, 394], dtype='int64')
#
#
# AND
#     Extracted                  0      1
# 395       AND         AND16i16\t   395,
# 396       AND          AND16mi\t   396,
# 397       AND         AND16mi8\t   397,
# 398       AND          AND16mr\t   398,
# 399       AND          AND16ri\t   399,
# 400       AND         AND16ri8\t   400,
# 401       AND          AND16rm\t   401,
# 402       AND          AND16rr\t   402,
# 403       AND      AND16rr_REV\t   403,
# 404       AND         AND32i32\t   404,
# 405       AND          AND32mi\t   405,
# 406       AND         AND32mi8\t   406,
# 407       AND          AND32mr\t   407,
# 408       AND          AND32ri\t   408,
# 409       AND         AND32ri8\t   409,
# 410       AND          AND32rm\t   410,
# 411       AND          AND32rr\t   411,
# 412       AND      AND32rr_REV\t   412,
# 413       AND         AND64i32\t   413,
# 414       AND        AND64mi32\t   414,
# 415       AND         AND64mi8\t   415,
# 416       AND          AND64mr\t   416,
# 417       AND        AND64ri32\t   417,
# 418       AND         AND64ri8\t   418,
# 419       AND          AND64rm\t   419,
# 420       AND          AND64rr\t   420,
# 421       AND      AND64rr_REV\t   421,
# 422       AND           AND8i8\t   422,
# 423       AND           AND8mi\t   423,
# 424       AND          AND8mi8\t   424,
# 425       AND           AND8mr\t   425,
# 426       AND           AND8ri\t   426,
# 427       AND          AND8ri8\t   427,
# 428       AND           AND8rm\t   428,
# 429       AND           AND8rr\t   429,
# 430       AND       AND8rr_REV\t   430,
#
#
# Int64Index([395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407,
#             408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420,
#             421, 422, 423, 424, 425, 426, 427, 428, 429, 430],
#            dtype='int64')
#
#
# ANDN
#     Extracted               0      1
# 431      ANDN      ANDN32rm\t   431,
# 432      ANDN      ANDN32rr\t   432,
# 433      ANDN      ANDN64rm\t   433,
# 434      ANDN      ANDN64rr\t   434,
#
#
# Int64Index([431, 432, 433, 434], dtype='int64')
#
#
# ANDNPDrm
#     Extracted               0      1
# 435  ANDNPDrm      ANDNPDrm\t   435,
#
#
# Int64Index([435], dtype='int64')
#
#
# ANDNPDrr
#     Extracted               0      1
# 436  ANDNPDrr      ANDNPDrr\t   436,
#
#
# Int64Index([436], dtype='int64')
#
#
# ANDNPSrm
#     Extracted               0      1
# 437  ANDNPSrm      ANDNPSrm\t   437,
#
#
# Int64Index([437], dtype='int64')
#
#
# ANDNPSrr
#     Extracted               0      1
# 438  ANDNPSrr      ANDNPSrr\t   438,
#
#
# Int64Index([438], dtype='int64')
#
#
# ANDPDrm
#     Extracted              0      1
# 439   ANDPDrm      ANDPDrm\t   439,
#
#
# Int64Index([439], dtype='int64')
#
#
# ANDPDrr
#     Extracted              0      1
# 440   ANDPDrr      ANDPDrr\t   440,
#
#
# Int64Index([440], dtype='int64')
#
#
# ANDPSrm
#     Extracted              0      1
# 441   ANDPSrm      ANDPSrm\t   441,
#
#
# Int64Index([441], dtype='int64')
#
#
# ANDPSrr
#     Extracted              0      1
# 442   ANDPSrr      ANDPSrr\t   442,
#
#
# Int64Index([442], dtype='int64')
#
#
# ANNOTATION_LABEL
#           Extracted                       0    1
# 6  ANNOTATION_LABEL      ANNOTATION_LABEL\t   6,
#
#
# Int64Index([6], dtype='int64')
#
#
# ARPL
#     Extracted               0      1
# 443      ARPL      ARPL16mr\t   443,
# 444      ARPL      ARPL16rr\t   444,
#
#
# Int64Index([443, 444], dtype='int64')
#
#
# AVX
#     Extracted                              0      1
# 188       AVX              AVX1_SETALLONES\t   188,
# 189       AVX              AVX2_SETALLONES\t   189,
# 190       AVX              AVX512_128_SET0\t   190,
# 191       AVX              AVX512_256_SET0\t   191,
# 192       AVX              AVX512_512_SET0\t   192,
# 193       AVX        AVX512_512_SETALLONES\t   193,
# 194       AVX      AVX512_512_SEXT_MASK_32\t   194,
# 195       AVX      AVX512_512_SEXT_MASK_64\t   195,
# 196       AVX            AVX512_FsFLD0F128\t   196,
# 197       AVX              AVX512_FsFLD0SD\t   197,
# 198       AVX              AVX512_FsFLD0SS\t   198,
#
#
# Int64Index([188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198], dtype='int64')
#
#
# AVX_SET
#     Extracted               0      1
# 199   AVX_SET      AVX_SET0\t   199,
#
#
# Int64Index([199], dtype='int64')
#
#
# BEXTR
#     Extracted                0      1
# 445     BEXTR      BEXTR32rm\t   445,
# 446     BEXTR      BEXTR32rr\t   446,
# 447     BEXTR      BEXTR64rm\t   447,
# 448     BEXTR      BEXTR64rr\t   448,
#
#
# Int64Index([445, 446, 447, 448], dtype='int64')
#
#
# BEXTRI
#     Extracted                 0      1
# 449    BEXTRI      BEXTRI32mi\t   449,
# 450    BEXTRI      BEXTRI32ri\t   450,
# 451    BEXTRI      BEXTRI64mi\t   451,
# 452    BEXTRI      BEXTRI64ri\t   452,
#
#
# Int64Index([449, 450, 451, 452], dtype='int64')
#
#
# BLCFILL
#     Extracted                  0      1
# 453   BLCFILL      BLCFILL32rm\t   453,
# 454   BLCFILL      BLCFILL32rr\t   454,
# 455   BLCFILL      BLCFILL64rm\t   455,
# 456   BLCFILL      BLCFILL64rr\t   456,
#
#
# Int64Index([453, 454, 455, 456], dtype='int64')
#
#
# BLCI
#     Extracted               0      1
# 457      BLCI      BLCI32rm\t   457,
# 458      BLCI      BLCI32rr\t   458,
# 459      BLCI      BLCI64rm\t   459,
# 460      BLCI      BLCI64rr\t   460,
#
#
# Int64Index([457, 458, 459, 460], dtype='int64')
# BLCIC
#     Extracted                0      1
# 461     BLCIC      BLCIC32rm\t   461,
# 462     BLCIC      BLCIC32rr\t   462,
# 463     BLCIC      BLCIC64rm\t   463,
# 464     BLCIC      BLCIC64rr\t   464,
#
#
# Int64Index([461, 462, 463, 464], dtype='int64')
#
#
# BLCMSK
#     Extracted                 0      1
# 465    BLCMSK      BLCMSK32rm\t   465,
# 466    BLCMSK      BLCMSK32rr\t   466,
# 467    BLCMSK      BLCMSK64rm\t   467,
# 468    BLCMSK      BLCMSK64rr\t   468,
#
#
# Int64Index([465, 466, 467, 468], dtype='int64')
#
#
# BLCS
#     Extracted               0      1
# 469      BLCS      BLCS32rm\t   469,
# 470      BLCS      BLCS32rr\t   470,
# 471      BLCS      BLCS64rm\t   471,
# 472      BLCS      BLCS64rr\t   472,
#
#
# Int64Index([469, 470, 471, 472], dtype='int64')
#
#
# BLENDPDrmi
#       Extracted                 0      1
# 473  BLENDPDrmi      BLENDPDrmi\t   473,
#
#
# Int64Index([473], dtype='int64')
#
#
# BLENDPDrri
#       Extracted                 0      1
# 474  BLENDPDrri      BLENDPDrri\t   474,
#
#
# Int64Index([474], dtype='int64')
#
#
# BLENDPSrmi
#       Extracted                 0      1
# 475  BLENDPSrmi      BLENDPSrmi\t   475,
#
#
# Int64Index([475], dtype='int64')
#
#
# BLENDPSrri
#       Extracted                 0      1
# 476  BLENDPSrri      BLENDPSrri\t   476,
#
#
# Int64Index([476], dtype='int64')
#
#
# BLENDVPDrm
#       Extracted                  0      1
# 477  BLENDVPDrm      BLENDVPDrm0\t   477,
#
#
# Int64Index([477], dtype='int64')
#
#
# BLENDVPDrr
#       Extracted                  0      1
# 478  BLENDVPDrr      BLENDVPDrr0\t   478,
#
#
# Int64Index([478], dtype='int64')
#
#
# BLENDVPSrm
#       Extracted                  0      1
# 479  BLENDVPSrm      BLENDVPSrm0\t   479,
#
#
# Int64Index([479], dtype='int64')
#
#
# BLENDVPSrr
#       Extracted                  0      1
# 480  BLENDVPSrr      BLENDVPSrr0\t   480,
#
#
# Int64Index([480], dtype='int64')
#
#
# BLSFILL
#     Extracted                  0      1
# 481   BLSFILL      BLSFILL32rm\t   481,
# 482   BLSFILL      BLSFILL32rr\t   482,
# 483   BLSFILL      BLSFILL64rm\t   483,
# 484   BLSFILL      BLSFILL64rr\t   484,
#
#
# Int64Index([481, 482, 483, 484], dtype='int64')
#
#
# BLSI
#     Extracted               0      1
# 485      BLSI      BLSI32rm\t   485,
# 486      BLSI      BLSI32rr\t   486,
# 487      BLSI      BLSI64rm\t   487,
# 488      BLSI      BLSI64rr\t   488,
#
#
# Int64Index([485, 486, 487, 488], dtype='int64')
#
#
# BLSIC
#     Extracted                0      1
# 489     BLSIC      BLSIC32rm\t   489,
# 490     BLSIC      BLSIC32rr\t   490,
# 491     BLSIC      BLSIC64rm\t   491,
# 492     BLSIC      BLSIC64rr\t   492,
#
#
# Int64Index([489, 490, 491, 492], dtype='int64')
#
#
# BLSMSK
#     Extracted                 0      1
# 493    BLSMSK      BLSMSK32rm\t   493,
# 494    BLSMSK      BLSMSK32rr\t   494,
# 495    BLSMSK      BLSMSK64rm\t   495,
# 496    BLSMSK      BLSMSK64rr\t   496,
#
#
# Int64Index([493, 494, 495, 496], dtype='int64')
#
#
# BLSR
#     Extracted               0      1
# 497      BLSR      BLSR32rm\t   497,
# 498      BLSR      BLSR32rr\t   498,
# 499      BLSR      BLSR64rm\t   499,
# 500      BLSR      BLSR64rr\t   500,
#
#
# Int64Index([497, 498, 499, 500], dtype='int64')
#
#
# BNDCL
#     Extracted                0      1
# 501     BNDCL      BNDCL32rm\t   501,
# 502     BNDCL      BNDCL32rr\t   502,
# 503     BNDCL      BNDCL64rm\t   503,
# 504     BNDCL      BNDCL64rr\t   504,
#
#
# Int64Index([501, 502, 503, 504], dtype='int64')
#
#
# BNDCN
#     Extracted                0      1
# 505     BNDCN      BNDCN32rm\t   505,
# 506     BNDCN      BNDCN32rr\t   506,
# 507     BNDCN      BNDCN64rm\t   507,
# 508     BNDCN      BNDCN64rr\t   508,
#
#
# Int64Index([505, 506, 507, 508], dtype='int64')
#
#
# BNDCU
#     Extracted                0      1
# 509     BNDCU      BNDCU32rm\t   509,
# 510     BNDCU      BNDCU32rr\t   510,
# 511     BNDCU      BNDCU64rm\t   511,
# 512     BNDCU      BNDCU64rr\t   512,
#
#
# Int64Index([509, 510, 511, 512], dtype='int64')
#
#
# BNDLDXrm
#     Extracted               0      1
# 513  BNDLDXrm      BNDLDXrm\t   513,
#
#
# Int64Index([513], dtype='int64')
#
#
# BNDMK
#     Extracted                0      1
# 514     BNDMK      BNDMK32rm\t   514,
# 515     BNDMK      BNDMK64rm\t   515,
#
#
# Int64Index([514, 515], dtype='int64')
#
#
# BNDMOV
#     Extracted                 0      1
# 516    BNDMOV      BNDMOV32mr\t   516,
# 517    BNDMOV      BNDMOV32rm\t   517,
# 518    BNDMOV      BNDMOV64mr\t   518,
# 519    BNDMOV      BNDMOV64rm\t   519,
#
#
# Int64Index([516, 517, 518, 519], dtype='int64')
#
#
# BNDMOVrr
#     Extracted               0      1
# 520  BNDMOVrr      BNDMOVrr\t   520,
#
#
# Int64Index([520], dtype='int64')
#
#
# BNDMOVrr_REV
#         Extracted                   0      1
# 521  BNDMOVrr_REV      BNDMOVrr_REV\t   521,
#
#
# Int64Index([521], dtype='int64')
#
#
# BNDSTXmr
#     Extracted               0      1
# 522  BNDSTXmr      BNDSTXmr\t   522,
#
#
# Int64Index([522], dtype='int64')
#
#
# BOUNDS
#     Extracted                 0      1
# 523    BOUNDS      BOUNDS16rm\t   523,
# 524    BOUNDS      BOUNDS32rm\t   524,
#
#
# Int64Index([523, 524], dtype='int64')
#
#
# BSF
#     Extracted              0      1
# 525       BSF      BSF16rm\t   525,
# 526       BSF      BSF16rr\t   526,
# 527       BSF      BSF32rm\t   527,
# 528       BSF      BSF32rr\t   528,
# 529       BSF      BSF64rm\t   529,
# 530       BSF      BSF64rr\t   530,
#
#
# Int64Index([525, 526, 527, 528, 529, 530], dtype='int64')
#
#
# BSR
#     Extracted              0      1
# 531       BSR      BSR16rm\t   531,
# 532       BSR      BSR16rr\t   532,
# 533       BSR      BSR32rm\t   533,
# 534       BSR      BSR32rr\t   534,
# 535       BSR      BSR64rm\t   535,
# 536       BSR      BSR64rr\t   536,
#
#
# Int64Index([531, 532, 533, 534, 535, 536], dtype='int64')
#
#
# BSWAP
#     Extracted                   0      1
# 537     BSWAP      BSWAP16r_BAD\t   537,
# 538     BSWAP          BSWAP32r\t   538,
# 539     BSWAP          BSWAP64r\t   539,
#
#
# Int64Index([537, 538, 539], dtype='int64')
#
#
# BT
#     Extracted              0      1
# 540        BT      BT16mi8\t   540,
# 541        BT       BT16mr\t   541,
# 542        BT      BT16ri8\t   542,
# 543        BT       BT16rr\t   543,
# 544        BT      BT32mi8\t   544,
# 545        BT       BT32mr\t   545,
# 546        BT      BT32ri8\t   546,
# 547        BT       BT32rr\t   547,
# 548        BT      BT64mi8\t   548,
# 549        BT       BT64mr\t   549,
# 550        BT      BT64ri8\t   550,
# 551        BT       BT64rr\t   551,
#
#
# Int64Index([540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551], dtype='int64')
#
#
# BTC
#     Extracted               0      1
# 552       BTC      BTC16mi8\t   552,
# 553       BTC       BTC16mr\t   553,
# 554       BTC      BTC16ri8\t   554,
# 555       BTC       BTC16rr\t   555,
# 556       BTC      BTC32mi8\t   556,
# 557       BTC       BTC32mr\t   557,
# 558       BTC      BTC32ri8\t   558,
# 559       BTC       BTC32rr\t   559,
# 560       BTC      BTC64mi8\t   560,
# 561       BTC       BTC64mr\t   561,
# 562       BTC      BTC64ri8\t   562,
# 563       BTC       BTC64rr\t   563,
#
#
# Int64Index([552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563], dtype='int64')
#
#
# BTR
#     Extracted               0      1
# 564       BTR      BTR16mi8\t   564,
# 565       BTR       BTR16mr\t   565,
# 566       BTR      BTR16ri8\t   566,
# 567       BTR       BTR16rr\t   567,
# 568       BTR      BTR32mi8\t   568,
# 569       BTR       BTR32mr\t   569,
# 570       BTR      BTR32ri8\t   570,
# 571       BTR       BTR32rr\t   571,
# 572       BTR      BTR64mi8\t   572,
# 573       BTR       BTR64mr\t   573,
# 574       BTR      BTR64ri8\t   574,
# 575       BTR       BTR64rr\t   575,
#
#
# Int64Index([564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575], dtype='int64')
#
#
# BTS
#     Extracted               0      1
# 576       BTS      BTS16mi8\t   576,
# 577       BTS       BTS16mr\t   577,
# 578       BTS      BTS16ri8\t   578,
# 579       BTS       BTS16rr\t   579,
# 580       BTS      BTS32mi8\t   580,
# 581       BTS       BTS32mr\t   581,
# 582       BTS      BTS32ri8\t   582,
# 583       BTS       BTS32rr\t   583,
# 584       BTS      BTS64mi8\t   584,
# 585       BTS       BTS64mr\t   585,
# 586       BTS      BTS64ri8\t   586,
# 587       BTS       BTS64rr\t   587,
#
#
# Int64Index([576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587], dtype='int64')
#
#
# BUNDLE
#    Extracted             0     1
# 17    BUNDLE      BUNDLE\t   17,
#
#
# Int64Index([17], dtype='int64')
#
#
# BZHI
#     Extracted               0      1
# 588      BZHI      BZHI32rm\t   588,
# 589      BZHI      BZHI32rr\t   589,
# 590      BZHI      BZHI64rm\t   590,
# 591      BZHI      BZHI64rr\t   591,
#
#
# Int64Index([588, 589, 590, 591], dtype='int64')
#
#
# CALL
#     Extracted                    0      1
# 592      CALL            CALL16m\t   592,
# 593      CALL         CALL16m_NT\t   593,
# 594      CALL            CALL16r\t   594,
# 595      CALL         CALL16r_NT\t   595,
# 596      CALL            CALL32m\t   596,
# 597      CALL         CALL32m_NT\t   597,
# 598      CALL            CALL32r\t   598,
# 599      CALL         CALL32r_NT\t   599,
# 600      CALL            CALL64m\t   600,
# 601      CALL         CALL64m_NT\t   601,
# 602      CALL      CALL64pcrel32\t   602,
# 603      CALL            CALL64r\t   603,
# 604      CALL         CALL64r_NT\t   604,
#
#
# Int64Index([592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604], dtype='int64')
#
#
# CALLpcrel
#      Extracted                  0      1
# 605  CALLpcrel      CALLpcrel16\t   605,
# 606  CALLpcrel      CALLpcrel32\t   606,
#
#
# Int64Index([605, 606], dtype='int64')
#
#
# CATCHPAD
#     Extracted               0      1
# 607  CATCHPAD      CATCHPAD\t   607,
#
#
# Int64Index([607], dtype='int64')
#
#
# CATCHRET
#     Extracted               0      1
# 608  CATCHRET      CATCHRET\t   608,
#
#
# Int64Index([608], dtype='int64')
#
#
# CBW
#     Extracted          0      1
# 609       CBW      CBW\t   609,
#
#
# Int64Index([609], dtype='int64')
#
#
# CDQ
#     Extracted          0      1
# 610       CDQ      CDQ\t   610,
#
#
# Int64Index([610], dtype='int64')
#
#
# CDQE
#     Extracted           0      1
# 611      CDQE      CDQE\t   611,
#
#
# Int64Index([611], dtype='int64')
#
#
# CFI_INSTRUCTION
#          Extracted                      0    1
# 3  CFI_INSTRUCTION      CFI_INSTRUCTION\t   3,
#
#
# Int64Index([3], dtype='int64')
#
#
# CHS_F
#     Extracted            0      1
# 612     CHS_F      CHS_F\t   612,
#
#
# Int64Index([612], dtype='int64')
#
#
# CHS_Fp
#     Extracted               0      1
# 613    CHS_Fp      CHS_Fp32\t   613,
# 614    CHS_Fp      CHS_Fp64\t   614,
# 615    CHS_Fp      CHS_Fp80\t   615,
#
#
# Int64Index([613, 614, 615], dtype='int64')
#
#
# CLAC
#     Extracted           0      1
# 616      CLAC      CLAC\t   616,
#
#
# Int64Index([616], dtype='int64')
#
#
# CLC
#     Extracted          0      1
# 617       CLC      CLC\t   617,
#
#
# Int64Index([617], dtype='int64')
#
#
# CLD
#     Extracted          0      1
# 618       CLD      CLD\t   618,
#
#
# Int64Index([618], dtype='int64')
#
#
# CLDEMOTE
#     Extracted               0      1
# 619  CLDEMOTE      CLDEMOTE\t   619,
#
#
# Int64Index([619], dtype='int64')
#
#
# CLEANUPRET
#       Extracted                 0      1
# 620  CLEANUPRET      CLEANUPRET\t   620,
#
#
# Int64Index([620], dtype='int64')
#
#
# CLFLUSH
#     Extracted              0      1
# 621   CLFLUSH      CLFLUSH\t   621,
#
#
# Int64Index([621], dtype='int64')
#
#
# CLFLUSHOPT
#       Extracted                 0      1
# 622  CLFLUSHOPT      CLFLUSHOPT\t   622,
#
#
# Int64Index([622], dtype='int64')
#
#
# CLGI
#     Extracted           0      1
# 623      CLGI      CLGI\t   623,
#
#
# Int64Index([623], dtype='int64')
#
#
# CLI
#     Extracted          0      1
# 624       CLI      CLI\t   624,
#
#
# Int64Index([624], dtype='int64')
#
#
# CLRSSBSY
#     Extracted               0      1
# 625  CLRSSBSY      CLRSSBSY\t   625,
#
#
# Int64Index([625], dtype='int64')
#
#
# CLTS
#     Extracted           0      1
# 626      CLTS      CLTS\t   626,
#
#
# Int64Index([626], dtype='int64')
#
#
# CLWB
#     Extracted           0      1
# 627      CLWB      CLWB\t   627,
#
#
# Int64Index([627], dtype='int64')
#
#
# CLZERO
#     Extracted                0      1
# 628    CLZERO      CLZERO32r\t   628,
# 629    CLZERO      CLZERO64r\t   629,
#
#
# Int64Index([628, 629], dtype='int64')
#
#
# CMC
#     Extracted          0      1
# 630       CMC      CMC\t   630,
#
#
# Int64Index([630], dtype='int64')
#
#
# CMOV
#     Extracted               0      1
# 631      CMOV      CMOV16rm\t   631,
# 632      CMOV      CMOV16rr\t   632,
# 633      CMOV      CMOV32rm\t   633,
# 634      CMOV      CMOV32rr\t   634,
# 635      CMOV      CMOV64rm\t   635,
# 636      CMOV      CMOV64rr\t   636,
#
#
# Int64Index([631, 632, 633, 634, 635, 636], dtype='int64')
#
#
# CMOVBE_F
#     Extracted               0      1
# 637  CMOVBE_F      CMOVBE_F\t   637,
#
#
# Int64Index([637], dtype='int64')
#
#
# CMOVBE_Fp
#      Extracted                  0      1
# 638  CMOVBE_Fp      CMOVBE_Fp32\t   638,
# 639  CMOVBE_Fp      CMOVBE_Fp64\t   639,
# 640  CMOVBE_Fp      CMOVBE_Fp80\t   640,
#
#
# Int64Index([638, 639, 640], dtype='int64')
#
#
# CMOVB_F
#     Extracted              0      1
# 641   CMOVB_F      CMOVB_F\t   641,
#
#
# Int64Index([641], dtype='int64')
#
#
# CMOVB_Fp
#     Extracted                 0      1
# 642  CMOVB_Fp      CMOVB_Fp32\t   642,
# 643  CMOVB_Fp      CMOVB_Fp64\t   643,
# 644  CMOVB_Fp      CMOVB_Fp80\t   644,
#
#
# Int64Index([642, 643, 644], dtype='int64')
#
#
# CMOVE_F
#     Extracted              0      1
# 645   CMOVE_F      CMOVE_F\t   645,
#
#
# Int64Index([645], dtype='int64')
#
#
# CMOVE_Fp
#     Extracted                 0      1
# 646  CMOVE_Fp      CMOVE_Fp32\t   646,
# 647  CMOVE_Fp      CMOVE_Fp64\t   647,
# 648  CMOVE_Fp      CMOVE_Fp80\t   648,
#
#
# Int64Index([646, 647, 648], dtype='int64')
#
#
# CMOVNBE_F
#      Extracted                0      1
# 649  CMOVNBE_F      CMOVNBE_F\t   649,
#
#
# Int64Index([649], dtype='int64')
#
#
# CMOVNBE_Fp
#       Extracted                   0      1
# 650  CMOVNBE_Fp      CMOVNBE_Fp32\t   650,
# 651  CMOVNBE_Fp      CMOVNBE_Fp64\t   651,
# 652  CMOVNBE_Fp      CMOVNBE_Fp80\t   652,
#
#
# Int64Index([650, 651, 652], dtype='int64')
#
#
# CMOVNB_F
#     Extracted               0      1
# 653  CMOVNB_F      CMOVNB_F\t   653,
#
#
# Int64Index([653], dtype='int64')
#
#
# CMOVNB_Fp
#      Extracted                  0      1
# 654  CMOVNB_Fp      CMOVNB_Fp32\t   654,
# 655  CMOVNB_Fp      CMOVNB_Fp64\t   655,
# 656  CMOVNB_Fp      CMOVNB_Fp80\t   656,
#
#
# Int64Index([654, 655, 656], dtype='int64')
#
#
# CMOVNE_F
#     Extracted               0      1
# 657  CMOVNE_F      CMOVNE_F\t   657,
#
#
# Int64Index([657], dtype='int64')
#
#
# CMOVNE_Fp
#      Extracted                  0      1
# 658  CMOVNE_Fp      CMOVNE_Fp32\t   658,
# 659  CMOVNE_Fp      CMOVNE_Fp64\t   659,
# 660  CMOVNE_Fp      CMOVNE_Fp80\t   660,
#
#
# Int64Index([658, 659, 660], dtype='int64')
#
#
# CMOVNP_F
#     Extracted               0      1
# 661  CMOVNP_F      CMOVNP_F\t   661,
#
#
# Int64Index([661], dtype='int64')
#
#
# CMOVNP_Fp
#      Extracted                  0      1
# 662  CMOVNP_Fp      CMOVNP_Fp32\t   662,
# 663  CMOVNP_Fp      CMOVNP_Fp64\t   663,
# 664  CMOVNP_Fp      CMOVNP_Fp80\t   664,
#
#
# Int64Index([662, 663, 664], dtype='int64')
#
#
# CMOVP_F
#     Extracted              0      1
# 665   CMOVP_F      CMOVP_F\t   665,
#
#
# Int64Index([665], dtype='int64')
#
#
# CMOVP_Fp
#     Extracted                 0      1
# 666  CMOVP_Fp      CMOVP_Fp32\t   666,
# 667  CMOVP_Fp      CMOVP_Fp64\t   667,
# 668  CMOVP_Fp      CMOVP_Fp80\t   668,
#
#
# Int64Index([666, 667, 668], dtype='int64')
#
#
# CMOV_FR
#     Extracted                 0      1
# 669   CMOV_FR       CMOV_FR32\t   669,
# 670   CMOV_FR      CMOV_FR32X\t   670,
# 671   CMOV_FR       CMOV_FR64\t   671,
# 672   CMOV_FR      CMOV_FR64X\t   672,
#
#
# Int64Index([669, 670, 671, 672], dtype='int64')
#
#
# CMOV_GR
#     Extracted                0      1
# 673   CMOV_GR      CMOV_GR16\t   673,
# 674   CMOV_GR      CMOV_GR32\t   674,
# 675   CMOV_GR       CMOV_GR8\t   675,
#
#
# Int64Index([673, 674, 675], dtype='int64')
#
#
# CMOV_RFP
#     Extracted                 0      1
# 676  CMOV_RFP      CMOV_RFP32\t   676,
# 677  CMOV_RFP      CMOV_RFP64\t   677,
# 678  CMOV_RFP      CMOV_RFP80\t   678,
#
#
# Int64Index([676, 677, 678], dtype='int64')
#
#
# CMOV_VK
#     Extracted                0      1
# 679   CMOV_VK      CMOV_VK16\t   679,
# 680   CMOV_VK       CMOV_VK2\t   680,
# 681   CMOV_VK      CMOV_VK32\t   681,
# 682   CMOV_VK       CMOV_VK4\t   682,
# 683   CMOV_VK      CMOV_VK64\t   683,
# 684   CMOV_VK       CMOV_VK8\t   684,
#
#
# Int64Index([679, 680, 681, 682, 683, 684], dtype='int64')
#
#
# CMOV_VR
#     Extracted                  0      1
# 685   CMOV_VR       CMOV_VR128\t   685,
# 686   CMOV_VR      CMOV_VR128X\t   686,
# 687   CMOV_VR       CMOV_VR256\t   687,
# 688   CMOV_VR      CMOV_VR256X\t   688,
# 689   CMOV_VR       CMOV_VR512\t   689,
#
#
# Int64Index([685, 686, 687, 688, 689], dtype='int64')
#
#
# CMP
#     Extracted                  0      1
# 690       CMP         CMP16i16\t   690,
# 691       CMP          CMP16mi\t   691,
# 692       CMP         CMP16mi8\t   692,
# 693       CMP          CMP16mr\t   693,
# 694       CMP          CMP16ri\t   694,
# 695       CMP         CMP16ri8\t   695,
# 696       CMP          CMP16rm\t   696,
# 697       CMP          CMP16rr\t   697,
# 698       CMP      CMP16rr_REV\t   698,
# 699       CMP         CMP32i32\t   699,
# 700       CMP          CMP32mi\t   700,
# 701       CMP         CMP32mi8\t   701,
# 702       CMP          CMP32mr\t   702,
# 703       CMP          CMP32ri\t   703,
# 704       CMP         CMP32ri8\t   704,
# 705       CMP          CMP32rm\t   705,
# 706       CMP          CMP32rr\t   706,
# 707       CMP      CMP32rr_REV\t   707,
# 708       CMP         CMP64i32\t   708,
# 709       CMP        CMP64mi32\t   709,
# 710       CMP         CMP64mi8\t   710,
# 711       CMP          CMP64mr\t   711,
# 712       CMP        CMP64ri32\t   712,
# 713       CMP         CMP64ri8\t   713,
# 714       CMP          CMP64rm\t   714,
# 715       CMP          CMP64rr\t   715,
# 716       CMP      CMP64rr_REV\t   716,
# 717       CMP           CMP8i8\t   717,
# 718       CMP           CMP8mi\t   718,
# 719       CMP          CMP8mi8\t   719,
# 720       CMP           CMP8mr\t   720,
# 721       CMP           CMP8ri\t   721,
# 722       CMP          CMP8ri8\t   722,
# 723       CMP           CMP8rm\t   723,
# 724       CMP           CMP8rr\t   724,
# 725       CMP       CMP8rr_REV\t   725,
#
#
# Int64Index([690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702,
#             703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715,
#             716, 717, 718, 719, 720, 721, 722, 723, 724, 725],
#            dtype='int64')
#
#
# CMPPDrmi
#     Extracted               0      1
# 726  CMPPDrmi      CMPPDrmi\t   726,
#
#
# Int64Index([726], dtype='int64')
#
#
# CMPPDrri
#     Extracted               0      1
# 727  CMPPDrri      CMPPDrri\t   727,
#
#
# Int64Index([727], dtype='int64')
#
#
# CMPPSrmi
#     Extracted               0      1
# 728  CMPPSrmi      CMPPSrmi\t   728,
#
#
# Int64Index([728], dtype='int64')
#
#
# CMPPSrri
#     Extracted               0      1
# 729  CMPPSrri      CMPPSrri\t   729,
#
#
# Int64Index([729], dtype='int64')
#
#
# CMPSB
#     Extracted            0      1
# 730     CMPSB      CMPSB\t   730,
#
#
# Int64Index([730], dtype='int64')
#
#
# CMPSDrm
#     Extracted              0      1
# 731   CMPSDrm      CMPSDrm\t   731,
#
#
# Int64Index([731], dtype='int64')
#
#
# CMPSDrm_Int
#        Extracted                  0      1
# 732  CMPSDrm_Int      CMPSDrm_Int\t   732,
#
#
# Int64Index([732], dtype='int64')
#
#
# CMPSDrr
#     Extracted              0      1
# 733   CMPSDrr      CMPSDrr\t   733,
#
#
# Int64Index([733], dtype='int64')
#
#
# CMPSDrr_Int
#        Extracted                  0      1
# 734  CMPSDrr_Int      CMPSDrr_Int\t   734,
#
#
# Int64Index([734], dtype='int64')
#
#
# CMPSL
#     Extracted            0      1
# 735     CMPSL      CMPSL\t   735,
#
#
# Int64Index([735], dtype='int64')
#
#
# CMPSQ
#     Extracted            0      1
# 736     CMPSQ      CMPSQ\t   736,
#
#
# Int64Index([736], dtype='int64')
#
#
# CMPSSrm
#     Extracted              0      1
# 737   CMPSSrm      CMPSSrm\t   737,
#
#
# Int64Index([737], dtype='int64')
#
#
# CMPSSrm_Int
#        Extracted                  0      1
# 738  CMPSSrm_Int      CMPSSrm_Int\t   738,
#
#
# Int64Index([738], dtype='int64')
#
#
# CMPSSrr
#     Extracted              0      1
# 739   CMPSSrr      CMPSSrr\t   739,
#
#
# Int64Index([739], dtype='int64')
#
#
# CMPSSrr_Int
#        Extracted                  0      1
# 740  CMPSSrr_Int      CMPSSrr_Int\t   740,
#
#
# Int64Index([740], dtype='int64')
#
#
# CMPSW
#     Extracted            0      1
# 741     CMPSW      CMPSW\t   741,
#
#
# Int64Index([741], dtype='int64')
#
#
# CMPXCHG
#     Extracted                  0      1
# 742   CMPXCHG       CMPXCHG16B\t   742,
# 743   CMPXCHG      CMPXCHG16rm\t   743,
# 744   CMPXCHG      CMPXCHG16rr\t   744,
# 745   CMPXCHG      CMPXCHG32rm\t   745,
# 746   CMPXCHG      CMPXCHG32rr\t   746,
# 747   CMPXCHG      CMPXCHG64rm\t   747,
# 748   CMPXCHG      CMPXCHG64rr\t   748,
# 749   CMPXCHG        CMPXCHG8B\t   749,
# 750   CMPXCHG       CMPXCHG8rm\t   750,
# 751   CMPXCHG       CMPXCHG8rr\t   751,
#
#
# Int64Index([742, 743, 744, 745, 746, 747, 748, 749, 750, 751], dtype='int64')
#
#
# COMISDrm
#     Extracted               0      1
# 752  COMISDrm      COMISDrm\t   752,
#
#
# Int64Index([752], dtype='int64')
#
#
# COMISDrm_Int
#         Extracted                   0      1
# 753  COMISDrm_Int      COMISDrm_Int\t   753,
#
#
# Int64Index([753], dtype='int64')
#
#
# COMISDrr
#     Extracted               0      1
# 754  COMISDrr      COMISDrr\t   754,
#
#
# Int64Index([754], dtype='int64')
#
#
# COMISDrr_Int
#         Extracted                   0      1
# 755  COMISDrr_Int      COMISDrr_Int\t   755,
#
#
# Int64Index([755], dtype='int64')
#
#
# COMISSrm
#     Extracted               0      1
# 756  COMISSrm      COMISSrm\t   756,
#
#
# Int64Index([756], dtype='int64')
#
#
# COMISSrm_Int
#         Extracted                   0      1
# 757  COMISSrm_Int      COMISSrm_Int\t   757,
#
#
# Int64Index([757], dtype='int64')
#
#
# COMISSrr
#     Extracted               0      1
# 758  COMISSrr      COMISSrr\t   758,
#
#
# Int64Index([758], dtype='int64')
#
#
# COMISSrr_Int
#         Extracted                   0      1
# 759  COMISSrr_Int      COMISSrr_Int\t   759,
#
#
# Int64Index([759], dtype='int64')
#
#
# COMP_FST
#     Extracted                 0      1
# 760  COMP_FST      COMP_FST0r\t   760,
#
#
# Int64Index([760], dtype='int64')
#
#
# COM_FIPr
#     Extracted               0      1
# 761  COM_FIPr      COM_FIPr\t   761,
#
#
# Int64Index([761], dtype='int64')
#
#
# COM_FIr
#     Extracted              0      1
# 762   COM_FIr      COM_FIr\t   762,
#
#
# Int64Index([762], dtype='int64')
#
#
# COM_FST
#     Extracted                0      1
# 763   COM_FST      COM_FST0r\t   763,
#
#
# Int64Index([763], dtype='int64')
#
#
# COM_FpIr
#     Extracted                 0      1
# 764  COM_FpIr      COM_FpIr32\t   764,
# 765  COM_FpIr      COM_FpIr64\t   765,
# 766  COM_FpIr      COM_FpIr80\t   766,
#
#
# Int64Index([764, 765, 766], dtype='int64')
#
#
# COM_Fpr
#     Extracted                0      1
# 767   COM_Fpr      COM_Fpr32\t   767,
# 768   COM_Fpr      COM_Fpr64\t   768,
# 769   COM_Fpr      COM_Fpr80\t   769,
#
#
# Int64Index([767, 768, 769], dtype='int64')
#
#
# COPY
#    Extracted           0     1
# 16      COPY      COPY\t   16,
#
#
# Int64Index([16], dtype='int64')
#
#
# COPY_TO_REGCLASS
#            Extracted                       0     1
# 12  COPY_TO_REGCLASS      COPY_TO_REGCLASS\t   12,
#
#
# Int64Index([12], dtype='int64')
#
#
# CPUID
#     Extracted            0      1
# 770     CPUID      CPUID\t   770,
#
#
# Int64Index([770], dtype='int64')
#
#
# CQO
#     Extracted          0      1
# 771       CQO      CQO\t   771,
#
#
# Int64Index([771], dtype='int64')
#
#
# CRC
#     Extracted                  0      1
# 772       CRC      CRC32r32m16\t   772,
# 773       CRC      CRC32r32m32\t   773,
# 774       CRC       CRC32r32m8\t   774,
# 775       CRC      CRC32r32r16\t   775,
# 776       CRC      CRC32r32r32\t   776,
# 777       CRC       CRC32r32r8\t   777,
# 778       CRC      CRC32r64m64\t   778,
# 779       CRC       CRC32r64m8\t   779,
# 780       CRC      CRC32r64r64\t   780,
# 781       CRC       CRC32r64r8\t   781,
#
#
# Int64Index([772, 773, 774, 775, 776, 777, 778, 779, 780, 781], dtype='int64')
#
#
# CS_PREFIX
#      Extracted                0      1
# 782  CS_PREFIX      CS_PREFIX\t   782,
#
#
# Int64Index([782], dtype='int64')
#
#
# CVTDQ
#     Extracted                 0      1
# 783     CVTDQ      CVTDQ2PDrm\t   783,
# 784     CVTDQ      CVTDQ2PDrr\t   784,
# 785     CVTDQ      CVTDQ2PSrm\t   785,
# 786     CVTDQ      CVTDQ2PSrr\t   786,
#
#
# Int64Index([783, 784, 785, 786], dtype='int64')
#
#
# CVTPD
#     Extracted                 0      1
# 787     CVTPD      CVTPD2DQrm\t   787,
# 788     CVTPD      CVTPD2DQrr\t   788,
# 789     CVTPD      CVTPD2PSrm\t   789,
# 790     CVTPD      CVTPD2PSrr\t   790,
#
#
# Int64Index([787, 788, 789, 790], dtype='int64')
#
#
# CVTPS
#     Extracted                 0      1
# 791     CVTPS      CVTPS2DQrm\t   791,
# 792     CVTPS      CVTPS2DQrr\t   792,
# 793     CVTPS      CVTPS2PDrm\t   793,
# 794     CVTPS      CVTPS2PDrr\t   794,
#
#
# Int64Index([791, 792, 793, 794], dtype='int64')
#
#
# CVTSD
#     Extracted                       0      1
# 795     CVTSD      CVTSD2SI64rm_Int\t   795,
# 796     CVTSD      CVTSD2SI64rr_Int\t   796,
# 797     CVTSD        CVTSD2SIrm_Int\t   797,
# 798     CVTSD        CVTSD2SIrr_Int\t   798,
# 799     CVTSD            CVTSD2SSrm\t   799,
# 800     CVTSD        CVTSD2SSrm_Int\t   800,
# 801     CVTSD            CVTSD2SSrr\t   801,
# 802     CVTSD        CVTSD2SSrr_Int\t   802,
#
#
# Int64Index([795, 796, 797, 798, 799, 800, 801, 802], dtype='int64')
#
#
# CVTSI
#     Extracted                       0      1
# 803     CVTSI            CVTSI2SDrm\t   803,
# 804     CVTSI        CVTSI2SDrm_Int\t   804,
# 805     CVTSI            CVTSI2SDrr\t   805,
# 806     CVTSI        CVTSI2SDrr_Int\t   806,
# 807     CVTSI            CVTSI2SSrm\t   807,
# 808     CVTSI        CVTSI2SSrm_Int\t   808,
# 809     CVTSI            CVTSI2SSrr\t   809,
# 810     CVTSI        CVTSI2SSrr_Int\t   810,
# 811     CVTSI          CVTSI642SDrm\t   811,
# 812     CVTSI      CVTSI642SDrm_Int\t   812,
# 813     CVTSI          CVTSI642SDrr\t   813,
# 814     CVTSI      CVTSI642SDrr_Int\t   814,
# 815     CVTSI          CVTSI642SSrm\t   815,
# 816     CVTSI      CVTSI642SSrm_Int\t   816,
# 817     CVTSI          CVTSI642SSrr\t   817,
# 818     CVTSI      CVTSI642SSrr_Int\t   818,
#
#
# Int64Index([803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815,
#             816, 817, 818],
#            dtype='int64')
#
#
# CVTSS
#     Extracted                       0      1
# 819     CVTSS            CVTSS2SDrm\t   819,
# 820     CVTSS        CVTSS2SDrm_Int\t   820,
# 821     CVTSS            CVTSS2SDrr\t   821,
# 822     CVTSS        CVTSS2SDrr_Int\t   822,
# 823     CVTSS      CVTSS2SI64rm_Int\t   823,
# 824     CVTSS      CVTSS2SI64rr_Int\t   824,
# 825     CVTSS        CVTSS2SIrm_Int\t   825,
# 826     CVTSS        CVTSS2SIrr_Int\t   826,
#
#
# Int64Index([819, 820, 821, 822, 823, 824, 825, 826], dtype='int64')
#
#
# CVTTPD
#     Extracted                  0      1
# 827    CVTTPD      CVTTPD2DQrm\t   827,
# 828    CVTTPD      CVTTPD2DQrr\t   828,
#
#
# Int64Index([827, 828], dtype='int64')
#
#
# CVTTPS
#     Extracted                  0      1
# 829    CVTTPS      CVTTPS2DQrm\t   829,
# 830    CVTTPS      CVTTPS2DQrr\t   830,
#
#
# Int64Index([829, 830], dtype='int64')
#
#
# CVTTSD
#     Extracted                        0      1
# 831    CVTTSD          CVTTSD2SI64rm\t   831,
# 832    CVTTSD      CVTTSD2SI64rm_Int\t   832,
# 833    CVTTSD          CVTTSD2SI64rr\t   833,
# 834    CVTTSD      CVTTSD2SI64rr_Int\t   834,
# 835    CVTTSD            CVTTSD2SIrm\t   835,
# 836    CVTTSD        CVTTSD2SIrm_Int\t   836,
# 837    CVTTSD            CVTTSD2SIrr\t   837,
# 838    CVTTSD        CVTTSD2SIrr_Int\t   838,
#
#
# Int64Index([831, 832, 833, 834, 835, 836, 837, 838], dtype='int64')
#
#
# CVTTSS
#     Extracted                        0      1
# 839    CVTTSS          CVTTSS2SI64rm\t   839,
# 840    CVTTSS      CVTTSS2SI64rm_Int\t   840,
# 841    CVTTSS          CVTTSS2SI64rr\t   841,
# 842    CVTTSS      CVTTSS2SI64rr_Int\t   842,
# 843    CVTTSS            CVTTSS2SIrm\t   843,
# 844    CVTTSS        CVTTSS2SIrm_Int\t   844,
# 845    CVTTSS            CVTTSS2SIrr\t   845,
# 846    CVTTSS        CVTTSS2SIrr_Int\t   846,
#
#
# Int64Index([839, 840, 841, 842, 843, 844, 845, 846], dtype='int64')
#
#
# CWD
#     Extracted          0      1
# 847       CWD      CWD\t   847,
#
#
# Int64Index([847], dtype='int64')
#
#
# CWDE
#     Extracted           0      1
# 848      CWDE      CWDE\t   848,
#
#
# Int64Index([848], dtype='int64')
#
#
# DAA
#     Extracted          0      1
# 849       DAA      DAA\t   849,
#
#
# Int64Index([849], dtype='int64')
# DAS
#     Extracted          0      1
# 850       DAS      DAS\t   850,
#
#
# Int64Index([850], dtype='int64')
#
#
# DATA
#     Extracted                    0      1
# 851      DATA      DATA16_PREFIX\t   851,
#
#
# Int64Index([851], dtype='int64')
#
#
# DBG_LABEL
#     Extracted                0     1
# 14  DBG_LABEL      DBG_LABEL\t   14,
#
#
# Int64Index([14], dtype='int64')
#
#
# DBG_VALUE
#     Extracted                0     1
# 13  DBG_VALUE      DBG_VALUE\t   13,
#
#
# Int64Index([13], dtype='int64')
#
#
# DEC
#     Extracted                 0      1
# 852       DEC          DEC16m\t   852,
# 853       DEC          DEC16r\t   853,
# 854       DEC      DEC16r_alt\t   854,
# 855       DEC          DEC32m\t   855,
# 856       DEC          DEC32r\t   856,
# 857       DEC      DEC32r_alt\t   857,
# 858       DEC          DEC64m\t   858,
# 859       DEC          DEC64r\t   859,
# 860       DEC           DEC8m\t   860,
# 861       DEC           DEC8r\t   861,
#
#
# Int64Index([852, 853, 854, 855, 856, 857, 858, 859, 860, 861], dtype='int64')
#
#
# DIV
#     Extracted             0      1
# 862       DIV      DIV16m\t   862,
# 863       DIV      DIV16r\t   863,
# 864       DIV      DIV32m\t   864,
# 865       DIV      DIV32r\t   865,
# 866       DIV      DIV64m\t   866,
# 867       DIV      DIV64r\t   867,
# 868       DIV       DIV8m\t   868,
# 869       DIV       DIV8r\t   869,
#
#
# Int64Index([862, 863, 864, 865, 866, 867, 868, 869], dtype='int64')
#
#
# DIVPDrm
#     Extracted              0      1
# 870   DIVPDrm      DIVPDrm\t   870,
#
#
# Int64Index([870], dtype='int64')
#
#
# DIVPDrr
#     Extracted              0      1
# 871   DIVPDrr      DIVPDrr\t   871,
#
#
# Int64Index([871], dtype='int64')
#
#
# DIVPSrm
#     Extracted              0      1
# 872   DIVPSrm      DIVPSrm\t   872,
#
#
# Int64Index([872], dtype='int64')
#
#
# DIVPSrr
#     Extracted              0      1
# 873   DIVPSrr      DIVPSrr\t   873,
#
#
# Int64Index([873], dtype='int64')
#
#
# DIVR_F
#     Extracted                0      1
# 874    DIVR_F      DIVR_F32m\t   874,
# 875    DIVR_F      DIVR_F64m\t   875,
#
#
# Int64Index([874, 875], dtype='int64')
#
#
# DIVR_FI
#     Extracted                 0      1
# 876   DIVR_FI      DIVR_FI16m\t   876,
# 877   DIVR_FI      DIVR_FI32m\t   877,
#
#
# Int64Index([876, 877], dtype='int64')
#
#
# DIVR_FPrST
#       Extracted                  0      1
# 878  DIVR_FPrST      DIVR_FPrST0\t   878,
#
#
# Int64Index([878], dtype='int64')
#
#
# DIVR_FST
#     Extracted                 0      1
# 879  DIVR_FST      DIVR_FST0r\t   879,
#
#
# Int64Index([879], dtype='int64')
#
#
# DIVR_Fp
#     Extracted                   0      1
# 880   DIVR_Fp        DIVR_Fp32m\t   880,
# 881   DIVR_Fp        DIVR_Fp64m\t   881,
# 882   DIVR_Fp      DIVR_Fp64m32\t   882,
# 883   DIVR_Fp      DIVR_Fp80m32\t   883,
# 884   DIVR_Fp      DIVR_Fp80m64\t   884,
#
#
# Int64Index([880, 881, 882, 883, 884], dtype='int64')
#
#
# DIVR_FpI
#     Extracted                    0      1
# 885  DIVR_FpI      DIVR_FpI16m32\t   885,
# 886  DIVR_FpI      DIVR_FpI16m64\t   886,
# 887  DIVR_FpI      DIVR_FpI16m80\t   887,
# 888  DIVR_FpI      DIVR_FpI32m32\t   888,
# 889  DIVR_FpI      DIVR_FpI32m64\t   889,
# 890  DIVR_FpI      DIVR_FpI32m80\t   890,
#
#
# Int64Index([885, 886, 887, 888, 889, 890], dtype='int64')
#
#
# DIVR_FrST
#      Extracted                 0      1
# 891  DIVR_FrST      DIVR_FrST0\t   891,
#
#
# Int64Index([891], dtype='int64')
#
#
# DIVSDrm
#     Extracted              0      1
# 892   DIVSDrm      DIVSDrm\t   892,
#
#
# Int64Index([892], dtype='int64')
#
#
# DIVSDrm_Int
#        Extracted                  0      1
# 893  DIVSDrm_Int      DIVSDrm_Int\t   893,
#
#
# Int64Index([893], dtype='int64')
#
#
# DIVSDrr
#     Extracted              0      1
# 894   DIVSDrr      DIVSDrr\t   894,
#
#
# Int64Index([894], dtype='int64')
#
#
# DIVSDrr_Int
#        Extracted                  0      1
# 895  DIVSDrr_Int      DIVSDrr_Int\t   895,
#
#
# Int64Index([895], dtype='int64')
#
#
# DIVSSrm
#     Extracted              0      1
# 896   DIVSSrm      DIVSSrm\t   896,
#
#
# Int64Index([896], dtype='int64')
#
#
# DIVSSrm_Int
#        Extracted                  0      1
# 897  DIVSSrm_Int      DIVSSrm_Int\t   897,
#
#
# Int64Index([897], dtype='int64')
#
#
# DIVSSrr
#     Extracted              0      1
# 898   DIVSSrr      DIVSSrr\t   898,
#
#
# ...
#
# Int64Index([15073], dtype='int64')
#
#
# VUNPCKLPSrm
#          Extracted                  0        1
# 15074  VUNPCKLPSrm      VUNPCKLPSrm\t   15074,
#
#
# Int64Index([15074], dtype='int64')
#
#
# VUNPCKLPSrr
#          Extracted                  0        1
# 15075  VUNPCKLPSrr      VUNPCKLPSrr\t   15075,
#
#
# Int64Index([15075], dtype='int64')
#
#
# VXORPDYrm
#        Extracted                0        1
# 15076  VXORPDYrm      VXORPDYrm\t   15076,
#
#
# Int64Index([15076], dtype='int64')
#
#
# VXORPDYrr
#        Extracted                0        1
# 15077  VXORPDYrr      VXORPDYrr\t   15077,
#
#
# Int64Index([15077], dtype='int64')
#
#
# VXORPDZ
#       Extracted                      0        1
# 15078   VXORPDZ         VXORPDZ128rm\t   15078,
# 15079   VXORPDZ        VXORPDZ128rmb\t   15079,
# 15080   VXORPDZ       VXORPDZ128rmbk\t   15080,
# 15081   VXORPDZ      VXORPDZ128rmbkz\t   15081,
# 15082   VXORPDZ        VXORPDZ128rmk\t   15082,
# 15083   VXORPDZ       VXORPDZ128rmkz\t   15083,
# 15084   VXORPDZ         VXORPDZ128rr\t   15084,
# 15085   VXORPDZ        VXORPDZ128rrk\t   15085,
# 15086   VXORPDZ       VXORPDZ128rrkz\t   15086,
# 15087   VXORPDZ         VXORPDZ256rm\t   15087,
# 15088   VXORPDZ        VXORPDZ256rmb\t   15088,
# 15089   VXORPDZ       VXORPDZ256rmbk\t   15089,
# 15090   VXORPDZ      VXORPDZ256rmbkz\t   15090,
# 15091   VXORPDZ        VXORPDZ256rmk\t   15091,
# 15092   VXORPDZ       VXORPDZ256rmkz\t   15092,
# 15093   VXORPDZ         VXORPDZ256rr\t   15093,
# 15094   VXORPDZ        VXORPDZ256rrk\t   15094,
# 15095   VXORPDZ       VXORPDZ256rrkz\t   15095,
#
#
# Int64Index([15078, 15079, 15080, 15081, 15082, 15083, 15084, 15085, 15086,
#             15087, 15088, 15089, 15090, 15091, 15092, 15093, 15094, 15095],
#            dtype='int64')
#
#
# VXORPDZrm
#        Extracted                0        1
# 15096  VXORPDZrm      VXORPDZrm\t   15096,
#
#
# Int64Index([15096], dtype='int64')
#
#
# VXORPDZrmb
#         Extracted                 0        1
# 15097  VXORPDZrmb      VXORPDZrmb\t   15097,
#
#
# Int64Index([15097], dtype='int64')
#
#
# VXORPDZrmbk
#          Extracted                  0        1
# 15098  VXORPDZrmbk      VXORPDZrmbk\t   15098,
#
#
# Int64Index([15098], dtype='int64')
#
#
# VXORPDZrmbkz
#           Extracted                   0        1
# 15099  VXORPDZrmbkz      VXORPDZrmbkz\t   15099,
#
#
# Int64Index([15099], dtype='int64')
#
#
# VXORPDZrmk
#         Extracted                 0        1
# 15100  VXORPDZrmk      VXORPDZrmk\t   15100,
#
#
# Int64Index([15100], dtype='int64')
#
#
# VXORPDZrmkz
#          Extracted                  0        1
# 15101  VXORPDZrmkz      VXORPDZrmkz\t   15101,
#
#
# Int64Index([15101], dtype='int64')
#
#
# VXORPDZrr
#        Extracted                0        1
# 15102  VXORPDZrr      VXORPDZrr\t   15102,
#
#
# Int64Index([15102], dtype='int64')
#
#
# VXORPDZrrk
#         Extracted                 0        1
# 15103  VXORPDZrrk      VXORPDZrrk\t   15103,
#
#
# Int64Index([15103], dtype='int64')
#
#
# VXORPDZrrkz
#          Extracted                  0        1
# 15104  VXORPDZrrkz      VXORPDZrrkz\t   15104,
#
#
# Int64Index([15104], dtype='int64')
#
#
# VXORPDrm
#       Extracted               0        1
# 15105  VXORPDrm      VXORPDrm\t   15105,
#
#
# Int64Index([15105], dtype='int64')
#
#
# VXORPDrr
#       Extracted               0        1
# 15106  VXORPDrr      VXORPDrr\t   15106,
#
#
# Int64Index([15106], dtype='int64')
#
#
# VXORPSYrm
#        Extracted                0        1
# 15107  VXORPSYrm      VXORPSYrm\t   15107,
#
#
# Int64Index([15107], dtype='int64')
#
#
# VXORPSYrr
#        Extracted                0        1
# 15108  VXORPSYrr      VXORPSYrr\t   15108,
#
#
# Int64Index([15108], dtype='int64')
#
#
# VXORPSZ
#       Extracted                      0        1
# 15109   VXORPSZ         VXORPSZ128rm\t   15109,
# 15110   VXORPSZ        VXORPSZ128rmb\t   15110,
# 15111   VXORPSZ       VXORPSZ128rmbk\t   15111,
# 15112   VXORPSZ      VXORPSZ128rmbkz\t   15112,
# 15113   VXORPSZ        VXORPSZ128rmk\t   15113,
# 15114   VXORPSZ       VXORPSZ128rmkz\t   15114,
# 15115   VXORPSZ         VXORPSZ128rr\t   15115,
# 15116   VXORPSZ        VXORPSZ128rrk\t   15116,
# 15117   VXORPSZ       VXORPSZ128rrkz\t   15117,
# 15118   VXORPSZ         VXORPSZ256rm\t   15118,
# 15119   VXORPSZ        VXORPSZ256rmb\t   15119,
# 15120   VXORPSZ       VXORPSZ256rmbk\t   15120,
# 15121   VXORPSZ      VXORPSZ256rmbkz\t   15121,
# 15122   VXORPSZ        VXORPSZ256rmk\t   15122,
# 15123   VXORPSZ       VXORPSZ256rmkz\t   15123,
# 15124   VXORPSZ         VXORPSZ256rr\t   15124,
# 15125   VXORPSZ        VXORPSZ256rrk\t   15125,
# 15126   VXORPSZ       VXORPSZ256rrkz\t   15126,
#
#
# Int64Index([15109, 15110, 15111, 15112, 15113, 15114, 15115, 15116, 15117,
#             15118, 15119, 15120, 15121, 15122, 15123, 15124, 15125, 15126],
#            dtype='int64')
#
#
# VXORPSZrm
#        Extracted                0        1
# 15127  VXORPSZrm      VXORPSZrm\t   15127,
#
#
# Int64Index([15127], dtype='int64')
#
#
# VXORPSZrmb
#         Extracted                 0        1
# 15128  VXORPSZrmb      VXORPSZrmb\t   15128,
#
#
# Int64Index([15128], dtype='int64')
#
#
# VXORPSZrmbk
#          Extracted                  0        1
# 15129  VXORPSZrmbk      VXORPSZrmbk\t   15129,
#
#
# Int64Index([15129], dtype='int64')
#
#
# VXORPSZrmbkz
#           Extracted                   0        1
# 15130  VXORPSZrmbkz      VXORPSZrmbkz\t   15130,
#
#
# Int64Index([15130], dtype='int64')
#
#
# VXORPSZrmk
#         Extracted                 0        1
# 15131  VXORPSZrmk      VXORPSZrmk\t   15131,
#
#
# Int64Index([15131], dtype='int64')
#
#
# VXORPSZrmkz
#          Extracted                  0        1
# 15132  VXORPSZrmkz      VXORPSZrmkz\t   15132,
#
#
# Int64Index([15132], dtype='int64')
#
#
# VXORPSZrr
#        Extracted                0        1
# 15133  VXORPSZrr      VXORPSZrr\t   15133,
#
#
# Int64Index([15133], dtype='int64')
#
#
# VXORPSZrrk
#         Extracted                 0        1
# 15134  VXORPSZrrk      VXORPSZrrk\t   15134,
#
#
# Int64Index([15134], dtype='int64')
#
#
# VXORPSZrrkz
#          Extracted                  0        1
# 15135  VXORPSZrrkz      VXORPSZrrkz\t   15135,
#
#
# Int64Index([15135], dtype='int64')
#
#
# VXORPSrm
#       Extracted               0        1
# 15136  VXORPSrm      VXORPSrm\t   15136,
#
#
# Int64Index([15136], dtype='int64')
#
#
# VXORPSrr
#       Extracted               0        1
# 15137  VXORPSrr      VXORPSrr\t   15137,
#
#
# Int64Index([15137], dtype='int64')
#
#
# VZEROALL
#       Extracted               0        1
# 15138  VZEROALL      VZEROALL\t   15138,
#
#
# Int64Index([15138], dtype='int64')
#
#
# VZEROUPPER
#         Extracted                 0        1
# 15139  VZEROUPPER      VZEROUPPER\t   15139,
#
#
# Int64Index([15139], dtype='int64')
#
#
# V_SET
#     Extracted             0      1
# 249     V_SET      V_SET0\t   249,
#
#
# Int64Index([249], dtype='int64')
# V_SETALLONES
#         Extracted                   0      1
# 250  V_SETALLONES      V_SETALLONES\t   250,
#
#
# Int64Index([250], dtype='int64')
#
#
# WAIT
#       Extracted           0        1
# 15140      WAIT      WAIT\t   15140,
#
#
# Int64Index([15140], dtype='int64')
#
#
# WBINVD
#       Extracted             0        1
# 15141    WBINVD      WBINVD\t   15141,
#
#
# Int64Index([15141], dtype='int64')
#
#
# WBNOINVD
#       Extracted               0        1
# 15142  WBNOINVD      WBNOINVD\t   15142,
#
#
# Int64Index([15142], dtype='int64')
#
#
# WIN_ALLOCA_
#          Extracted                    0        1
# 15143  WIN_ALLOCA_      WIN_ALLOCA_32\t   15143,
# 15144  WIN_ALLOCA_      WIN_ALLOCA_64\t   15144,
#
#
# Int64Index([15143, 15144], dtype='int64')
#
#
# WRFLAGS
#       Extracted                0        1
# 15145   WRFLAGS      WRFLAGS32\t   15145,
# 15146   WRFLAGS      WRFLAGS64\t   15146,
#
#
# Int64Index([15145, 15146], dtype='int64')
#
#
# WRFSBASE
#       Extracted                 0        1
# 15147  WRFSBASE        WRFSBASE\t   15147,
# 15148  WRFSBASE      WRFSBASE64\t   15148,
#
#
# Int64Index([15147, 15148], dtype='int64')
#
#
# WRGSBASE
#       Extracted                 0        1
# 15149  WRGSBASE        WRGSBASE\t   15149,
# 15150  WRGSBASE      WRGSBASE64\t   15150,
#
#
# Int64Index([15149, 15150], dtype='int64')
#
#
# WRMSR
#       Extracted            0        1
# 15151     WRMSR      WRMSR\t   15151,
#
#
# Int64Index([15151], dtype='int64')
#
#
# WRPKRUr
#       Extracted              0        1
# 15152   WRPKRUr      WRPKRUr\t   15152,
#
#
# Int64Index([15152], dtype='int64')
#
#
# WRSSD
#       Extracted            0        1
# 15153     WRSSD      WRSSD\t   15153,
#
#
# Int64Index([15153], dtype='int64')
#
#
# WRSSQ
#       Extracted            0        1
# 15154     WRSSQ      WRSSQ\t   15154,
#
#
# Int64Index([15154], dtype='int64')
#
#
# WRUSSD
#       Extracted             0        1
# 15155    WRUSSD      WRUSSD\t   15155,
#
#
# Int64Index([15155], dtype='int64')
#
#
# WRUSSQ
#       Extracted             0        1
# 15156    WRUSSQ      WRUSSQ\t   15156,
#
#
# Int64Index([15156], dtype='int64')
#
#
# XABORT
#       Extracted             0        1
# 15157    XABORT      XABORT\t   15157,
#
#
# Int64Index([15157], dtype='int64')
#
#
# XABORT_DEF
#       Extracted                 0      1
# 251  XABORT_DEF      XABORT_DEF\t   251,
#
#
# Int64Index([251], dtype='int64')
#
#
# XACQUIRE_PREFIX
#              Extracted                      0        1
# 15158  XACQUIRE_PREFIX      XACQUIRE_PREFIX\t   15158,
#
#
# Int64Index([15158], dtype='int64')
#
#
# XADD
#       Extracted               0        1
# 15159      XADD      XADD16rm\t   15159,
# 15160      XADD      XADD16rr\t   15160,
# 15161      XADD      XADD32rm\t   15161,
# 15162      XADD      XADD32rr\t   15162,
# 15163      XADD      XADD64rm\t   15163,
# 15164      XADD      XADD64rr\t   15164,
# 15165      XADD       XADD8rm\t   15165,
# 15166      XADD       XADD8rr\t   15166,
#
#
# Int64Index([15159, 15160, 15161, 15162, 15163, 15164, 15165, 15166], dtype='int64')
#
#
# XBEGIN
#       Extracted             0        1
# 15167    XBEGIN      XBEGIN\t   15167,
#
#
# Int64Index([15167], dtype='int64')
#
#
# XBEGIN_
#       Extracted               0        1
# 15168   XBEGIN_      XBEGIN_2\t   15168,
# 15169   XBEGIN_      XBEGIN_4\t   15169,
#
#
# Int64Index([15168, 15169], dtype='int64')
#
#
# XCHG
#       Extracted               0        1
# 15170      XCHG      XCHG16ar\t   15170,
# 15171      XCHG      XCHG16rm\t   15171,
# 15172      XCHG      XCHG16rr\t   15172,
# 15173      XCHG      XCHG32ar\t   15173,
# 15174      XCHG      XCHG32rm\t   15174,
# 15175      XCHG      XCHG32rr\t   15175,
# 15176      XCHG      XCHG64ar\t   15176,
# 15177      XCHG      XCHG64rm\t   15177,
# 15178      XCHG      XCHG64rr\t   15178,
# 15179      XCHG       XCHG8rm\t   15179,
# 15180      XCHG       XCHG8rr\t   15180,
#
#
# Int64Index([15170, 15171, 15172, 15173, 15174, 15175, 15176, 15177, 15178,
#             15179, 15180],
#            dtype='int64')
#
#
# XCH_F
#       Extracted            0        1
# 15181     XCH_F      XCH_F\t   15181,
#
#
# Int64Index([15181], dtype='int64')
#
#
# XCRYPTCBC
#        Extracted                0        1
# 15182  XCRYPTCBC      XCRYPTCBC\t   15182,
#
#
# Int64Index([15182], dtype='int64')
#
#
# XCRYPTCFB
#        Extracted                0        1
# 15183  XCRYPTCFB      XCRYPTCFB\t   15183,
#
#
# Int64Index([15183], dtype='int64')
#
#
# XCRYPTCTR
#        Extracted                0        1
# 15184  XCRYPTCTR      XCRYPTCTR\t   15184,
#
#
# Int64Index([15184], dtype='int64')
#
#
# XCRYPTECB
#        Extracted                0        1
# 15185  XCRYPTECB      XCRYPTECB\t   15185,
#
#
# Int64Index([15185], dtype='int64')
#
#
# XCRYPTOFB
#        Extracted                0        1
# 15186  XCRYPTOFB      XCRYPTOFB\t   15186,
#
#
# Int64Index([15186], dtype='int64')
#
#
# XEND
#       Extracted           0        1
# 15187      XEND      XEND\t   15187,
#
#
# Int64Index([15187], dtype='int64')
#
#
# XGETBV
#       Extracted             0        1
# 15188    XGETBV      XGETBV\t   15188,
#
#
# Int64Index([15188], dtype='int64')
#
#
# XLAT
#       Extracted           0        1
# 15189      XLAT      XLAT\t   15189,
#
#
# Int64Index([15189], dtype='int64')
#
#
# XOR
#       Extracted                  0        1
# 252         XOR         XOR32_FP\t     252,
# 253         XOR         XOR64_FP\t     253,
# 15190       XOR         XOR16i16\t   15190,
# 15191       XOR          XOR16mi\t   15191,
# 15192       XOR         XOR16mi8\t   15192,
# 15193       XOR          XOR16mr\t   15193,
# 15194       XOR          XOR16ri\t   15194,
# 15195       XOR         XOR16ri8\t   15195,
# 15196       XOR          XOR16rm\t   15196,
# 15197       XOR          XOR16rr\t   15197,
# 15198       XOR      XOR16rr_REV\t   15198,
# 15199       XOR         XOR32i32\t   15199,
# 15200       XOR          XOR32mi\t   15200,
# 15201       XOR         XOR32mi8\t   15201,
# 15202       XOR          XOR32mr\t   15202,
# 15203       XOR          XOR32ri\t   15203,
# 15204       XOR         XOR32ri8\t   15204,
# 15205       XOR          XOR32rm\t   15205,
# 15206       XOR          XOR32rr\t   15206,
# 15207       XOR      XOR32rr_REV\t   15207,
# 15208       XOR         XOR64i32\t   15208,
# 15209       XOR        XOR64mi32\t   15209,
# 15210       XOR         XOR64mi8\t   15210,
# 15211       XOR          XOR64mr\t   15211,
# 15212       XOR        XOR64ri32\t   15212,
# 15213       XOR         XOR64ri8\t   15213,
# 15214       XOR          XOR64rm\t   15214,
# 15215       XOR          XOR64rr\t   15215,
# 15216       XOR      XOR64rr_REV\t   15216,
# 15217       XOR           XOR8i8\t   15217,
# 15218       XOR           XOR8mi\t   15218,
# 15219       XOR          XOR8mi8\t   15219,
# 15220       XOR           XOR8mr\t   15220,
# 15221       XOR           XOR8ri\t   15221,
# 15222       XOR          XOR8ri8\t   15222,
# 15223       XOR           XOR8rm\t   15223,
# 15224       XOR           XOR8rr\t   15224,
# 15225       XOR       XOR8rr_REV\t   15225,
#
#
# Int64Index([  252,   253, 15190, 15191, 15192, 15193, 15194, 15195, 15196,
#             15197, 15198, 15199, 15200, 15201, 15202, 15203, 15204, 15205,
#             15206, 15207, 15208, 15209, 15210, 15211, 15212, 15213, 15214,
#             15215, 15216, 15217, 15218, 15219, 15220, 15221, 15222, 15223,
#             15224, 15225],
#            dtype='int64')
#
#
# XORPDrm
#       Extracted              0        1
# 15226   XORPDrm      XORPDrm\t   15226,
#
#
# Int64Index([15226], dtype='int64')
#
#
# XORPDrr
#       Extracted              0        1
# 15227   XORPDrr      XORPDrr\t   15227,
#
#
# Int64Index([15227], dtype='int64')
#
#
# XORPSrm
#       Extracted              0        1
# 15228   XORPSrm      XORPSrm\t   15228,
#
#
# Int64Index([15228], dtype='int64')
#
#
# XORPSrr
#       Extracted              0        1
# 15229   XORPSrr      XORPSrr\t   15229,
#
#
# Int64Index([15229], dtype='int64')
#
#
# XRELEASE_PREFIX
#              Extracted                      0        1
# 15230  XRELEASE_PREFIX      XRELEASE_PREFIX\t   15230,
#
#
# Int64Index([15230], dtype='int64')
#
#
# XRSTOR
#       Extracted               0        1
# 15231    XRSTOR        XRSTOR\t   15231,
# 15232    XRSTOR      XRSTOR64\t   15232,
#
#
# Int64Index([15231, 15232], dtype='int64')
#
#
# XRSTORS
#       Extracted                0        1
# 15233   XRSTORS        XRSTORS\t   15233,
# 15234   XRSTORS      XRSTORS64\t   15234,
#
#
# Int64Index([15233, 15234], dtype='int64')
#
#
# XSAVE
#       Extracted              0        1
# 15235     XSAVE        XSAVE\t   15235,
# 15236     XSAVE      XSAVE64\t   15236,
#
#
# Int64Index([15235, 15236], dtype='int64')
#
#
# XSAVEC
#       Extracted               0        1
# 15237    XSAVEC        XSAVEC\t   15237,
# 15238    XSAVEC      XSAVEC64\t   15238,
#
#
# Int64Index([15237, 15238], dtype='int64')
#
#
# XSAVEOPT
#       Extracted                 0        1
# 15239  XSAVEOPT        XSAVEOPT\t   15239,
# 15240  XSAVEOPT      XSAVEOPT64\t   15240,
#
#
# Int64Index([15239, 15240], dtype='int64')
#
#
# XSAVES
#       Extracted               0        1
# 15241    XSAVES        XSAVES\t   15241,
# 15242    XSAVES      XSAVES64\t   15242,
#
#
# Int64Index([15241, 15242], dtype='int64')
#
#
# XSETBV
#       Extracted             0        1
# 15243    XSETBV      XSETBV\t   15243,
#
#
# Int64Index([15243], dtype='int64')
#
#
# XSHA
#       Extracted              0        1
# 15244      XSHA        XSHA1\t   15244,
# 15245      XSHA      XSHA256\t   15245,
#
#
# Int64Index([15244, 15245], dtype='int64')
#
#
# XSTORE
#       Extracted             0        1
# 15246    XSTORE      XSTORE\t   15246,
#
#
# Int64Index([15246], dtype='int64')
#
#
# XTEST
#       Extracted            0        1
# 15247     XTEST      XTEST\t   15247,
#
#
# Int64Index([15247], dtype='int64')

# %%
print(len(grouped))
# Out:
# 5734

# %%
0 ADD
1 ADD
2 ADC
3 ADC
4 MUL
